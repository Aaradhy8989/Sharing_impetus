# %%
import pandas as pd
df = pd.read_csv("C:/Users/aarad/OneDrive/Desktop/2.12_Health_systems.csv")
df.head()
# Out:
#   Country_Region Province_State World_Bank_Name  Health_exp_pct_GDP_2016  \
# 0    Afghanistan            NaN     Afghanistan                     10.2
# 1        Albania            NaN         Albania                      6.7
# 2        Algeria            NaN         Algeria                      6.6
# 3        Andorra            NaN         Andorra                     10.4
# 4         Angola            NaN          Angola                      2.9
#
#    Health_exp_public_pct_2016  Health_exp_out_of_pocket_pct_2016  \
# 0                         5.1                               77.4
# 1                        41.4                               58.0
# 2                        67.7                               30.9
# 3                        49.1                               41.7
# 4                        44.1                               35.2
#
#    Health_exp_per_capita_USD_2016  per_capita_exp_PPP_2016  \
# 0                            57.2                    162.8
# ...

# %%
df.shape
# Out:
# (210, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 14 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Country_Region                        187 non-null    object
#  1   Province_State                        14 non-null     object
#  2   World_Bank_Name                       210 non-null    object
#  3   Health_exp_pct_GDP_2016               186 non-null    float64
#  4   Health_exp_public_pct_2016            186 non-null    float64
#  5   Health_exp_out_of_pocket_pct_2016     186 non-null    float64
#  6   Health_exp_per_capita_USD_2016        186 non-null    float64
#  7   per_capita_exp_PPP_2016               186 non-null    float64
#  8   External_health_exp_pct_2016          167 non-null    float64
#  9   Physicians_per_1000_2009-18           189 non-null    float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 14 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Country_Region                        187 non-null    object
#  1   Province_State                        14 non-null     object
#  2   World_Bank_Name                       210 non-null    object
#  3   Health_exp_pct_GDP_2016               186 non-null    float64
#  4   Health_exp_public_pct_2016            186 non-null    float64
#  5   Health_exp_out_of_pocket_pct_2016     186 non-null    float64
#  6   Health_exp_per_capita_USD_2016        186 non-null    float64
#  7   per_capita_exp_PPP_2016               186 non-null    float64
#  8   External_health_exp_pct_2016          167 non-null    float64
#  9   Physicians_per_1000_2009-18           189 non-null    float64
# ...

# %%
df['Province_State'].isnull()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 205    False
# 206     True
# 207     True
# 208     True
# 209     True
# Name: Province_State, Length: 210, dtype: bool

# %%
df = df.drop(['Province_State'], axis = 1)

# %%
df1 = df.dropna(how = 'any')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 65 entries, 1 to 200
# Data columns (total 13 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Country_Region                        65 non-null     object
#  1   World_Bank_Name                       65 non-null     object
#  2   Health_exp_pct_GDP_2016               65 non-null     float64
#  3   Health_exp_public_pct_2016            65 non-null     float64
#  4   Health_exp_out_of_pocket_pct_2016     65 non-null     float64
#  5   Health_exp_per_capita_USD_2016        65 non-null     float64
#  6   per_capita_exp_PPP_2016               65 non-null     float64
#  7   External_health_exp_pct_2016          65 non-null     float64
#  8   Physicians_per_1000_2009-18           65 non-null     float64
#  9   Nurse_midwife_per_1000_2009-18        65 non-null     float64
# ...

# %%
df.describe()
# Out:
#        Health_exp_pct_GDP_2016  Health_exp_public_pct_2016  \
# count               186.000000                  186.000000
# mean                  6.715054                   52.915054
# std                   2.976537                   21.957736
# min                   1.700000                    5.100000
# 25%                   4.500000                   36.825000
# 50%                   6.200000                   55.850000
# 75%                   8.375000                   70.600000
# max                  23.300000                   96.000000
#
#        Health_exp_out_of_pocket_pct_2016  Health_exp_per_capita_USD_2016  \
# count                         186.000000                      186.000000
# mean                           32.661828                     1037.004839
# std                            19.572777                     1712.592621
# min                             0.100000                       16.400000
# ...

# %%
import seaborn as sns

# %%
df1.corr()
# Out:
#                                       Health_exp_pct_GDP_2016  \
# Health_exp_pct_GDP_2016                              1.000000
# Health_exp_public_pct_2016                           0.330616
# Health_exp_out_of_pocket_pct_2016                   -0.327683
# Health_exp_per_capita_USD_2016                       0.597685
# per_capita_exp_PPP_2016                              0.590629
# External_health_exp_pct_2016                        -0.329481
# Physicians_per_1000_2009-18                          0.411371
# Nurse_midwife_per_1000_2009-18                       0.415643
# Specialist_surgical_per_1000_2008-18                 0.292955
# Completeness_of_birth_reg_2009-18                    0.072427
# Completeness_of_death_reg_2008-16                    0.224357
#
#                                       Health_exp_public_pct_2016  \
# Health_exp_pct_GDP_2016                                 0.330616
# Health_exp_public_pct_2016                              1.000000
# ...

# %%
import matplotlib.pyplot as plt

# %%
f, ax = plt.subplots(figsize=(11, 8))
sns.heatmap(df1.corr(), annot = True, linewidths=.5, ax=ax, cmap = 'viridis')

# %%
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(df.isnull(),cbar=False,yticklabels=False,cmap = 'YlGnBu')

# %%
l = df1.columns.values
number_of_columns=14
number_of_rows = len(l)-1/number_of_columns
plt.figure(figsize=(number_of_columns,5*number_of_rows))
for i in range(2,len(l)):
    plt.subplot(number_of_rows + 1,number_of_columns,i+1)
    sns.set_style('whitegrid')
    sns.boxplot(df1[l[i]],color='green',orient='v')

# %%
plt.figure(figsize=(2*number_of_columns,5*number_of_rows))
for i in range(2,len(l)):
    plt.subplot(number_of_rows + 1,number_of_columns,i+1)
    sns.distplot(df[l[i]],kde=True)
